# %%
import os

import time
import torch
import numpy as np
from sklearn import datasets, model_selection, metrics
import matplotlib.pyplot as plt
plt.style.use('ggplot')
import falkon
assert torch.cuda.is_available()

# %%
from falkon import LogisticFalkon, Falkon
from falkon.kernels import GaussianKernel
from falkon.options import FalkonOptions
from falkon.gsc_losses import WeightedCrossEntropyLoss

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cuda')

# %%
# Statistics                                                                                                                                                   
N_REF      = 200000
N_BKG      = 2000
N_SIG      = 0      
SIG_LOC    = 6.4
SIG_STD    = 0.16
# Samples weights N_D/N_R
N_R        = N_REF
N_D        = N_BKG

# parameters
M = 2000
SIGMA = 0.5
PENALTY = 1e-10

# %%
# poisson fluctuate the number of events in each sample
N_bkg_p = int(torch.distributions.Poisson(rate=N_BKG).sample())
N_sig_p = int(torch.distributions.Poisson(rate=N_SIG).sample())

# the reference rate will not have nuisance parameters
feature_ref_dist = torch.distributions.Exponential(rate=1)
# the data rate will have nuisance parameters   
feature_bkg_dist = torch.distributions.Exponential(rate=1)
feature_sig_dist = torch.distributions.Normal(loc=SIG_LOC, scale=SIG_STD)

print(f'bkg events = {N_bkg_p}; sig events = {N_sig_p}')
# Out:
# bkg events = 2000; sig events = 0

# %%
feature_ref  = feature_ref_dist.sample((N_REF,1))
feature_data = torch.cat(
    (
        feature_bkg_dist.sample((N_bkg_p, 1)),
        feature_sig_dist.sample((N_sig_p, 1))
    )
)

feature = torch.cat((feature_ref, feature_data), dim=0)

target_ref  = torch.zeros((N_REF, 1))
target_data = torch.ones((N_bkg_p + N_sig_p, 1))

target = torch.cat((target_ref, target_data), dim=0)

# %%
model_parameters = {
    'sigma' : SIGMA, # kernel lengthscale
    'penalty_list' : [PENALTY], # list of regularization parameters,
    'iter_list' : [1000], #list of number of CG iterations,
    'M' : M, #number of Nystrom centers,
    'keops_active': "auto", # optional, if it is used, pyKeOPS is used to speed-up computations
    'seed' : 123456 # (int or None), the model seed (used for Nystrom center selection) is manually set.
 }

# %% [markdown]
# build model

# %%
kernel = GaussianKernel(torch.Tensor([model_parameters['sigma']]))
cg_tol = 1e-7
keops_active = "no"
use_cpu = False
weight = N_BKG / N_REF

configuration = {
    'kernel' : kernel,
    'penalty_list' : model_parameters['penalty_list'],
    'iter_list' : model_parameters['iter_list'],
    'M' : model_parameters['M'],
    'options' : FalkonOptions(cg_tolerance=cg_tol, keops_active=keops_active, use_cpu=use_cpu, debug = False),
    'loss' : WeightedCrossEntropyLoss(kernel=kernel, neg_weight=weight),
    'seed' : model_parameters['seed']
}

model = LogisticFalkon(**configuration)
# model = Falkon(kernel=kernel, penalty=1e-10, M=model_parameters['M'], options=options)

# %%
model.fit(feature, target)
# Out:
# Iteration 0 - penalty 1.000000e-10 - sub-iterations 1000
# LogisticFalkon(M=3000, center_selection=<falkon.center_selection.UniformSelector object at 0x7ff6297a0e20>, iter_list=[1000], kernel=GaussianKernel(sigma=Parameter containing:
# tensor([0.3000])), loss=WeightedCrossEntropy(kernel=GaussianKernel(sigma=Parameter containing:
# tensor([0.3000]))), options=FalkonOptions(keops_acc_dtype='auto', keops_sum_scheme='auto', keops_active='no', keops_memory_slack=0.7, chol_force_in_core=False, chol_force_ooc=False, chol_par_blk_multiplier=2, pc_epsilon_32=1e-05, pc_epsilon_64=1e-13, cpu_preconditioner=False, cg_epsilon_32=1e-07, cg_epsilon_64=1e-15, cg_tolerance=1e-07, cg_full_gradient_every=10, cg_differential_convergence=False, debug=False, use_cpu=False, max_gpu_mem=inf, max_cpu_mem=inf, compute_arch_speed=False, no_single_kernel=True, min_cuda_pc_size_32=10000, min_cuda_pc_size_64=30000, min_cuda_iter_size_32=300000000, min_cuda_iter_size_64=900000000, never_store_kernel=False, store_kernel_d_threshold=1200, num_fmm_streams=2, memory_slack=0.9), penalty_list=[1e-10], seed=123456)

# %%
ref_pred, data_pred = model.predict(feature_ref), model.predict(feature_data)

# %%
def calculate_t(ref_pred, data_pred, weight):
    
    diff = weight*torch.sum(1-torch.exp(ref_pred))
    t = 2* (diff + torch.sum(data_pred).item())
    return t.item()

# %%
print(calculate_t(ref_pred,data_pred,weight))
# Out:
# 46.059486389160156

# %%
t_list=[]
for i in range(20):
    model.fit(feature, target)
    ref_pred, data_pred = model.predict(feature_ref), model.predict(feature_data)
    t_list.append(calculate_t(ref_pred,data_pred,weight))
# Out:
# Iteration 0 - penalty 1.000000e-10 - sub-iterations 1000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 3
#       1 t_list=[]
#       2 for i in range(20):
# ----> 3     model.fit(feature, target)
#       4     ref_pred, data_pred = model.predict(feature_ref), model.predict(feature_data)
#       5     t_list.append(calculate_t(ref_pred,data_pred,weight))
#
# File ~/miniconda3/envs/falkon-env/lib/python3.9/site-packages/falkon/models/logistic_falkon.py:251, in LogisticFalkon.fit(self, X, Y, Xts, Yts)
#     248         knmp_hess = self.loss.knmp_hess(X, ny_X, Y, inner_mmv_, precond.invT(sol_a), opt=self.options)
#     249         return precond.invAt(precond.invTt(knmp_hess).add_(sol_a.mul_(penalty_)))
# --> 251     optim_out = optim.solve(X0=None, B=grad_p, mmv=mmv, max_iter=max_iter)
#     252     beta_it -= precond.invA(optim_out)
#     254 t_elapsed += time.time() - t_s
#
# File ~/miniconda3/envs/falkon-env/lib/python3.9/site-packages/falkon/optim/conjgrad.py:138, in ConjugateGradient.solve(self, X0, B, mmv, max_iter, callback)
#     135     if X.is_cuda:
#     136         # addmm_ may not be finished yet causing mmv to get stale inputs.
#     137         torch.cuda.synchronize()
# --> 138     R = B - mmv(X)
#     139 else:
#     140     # R -= AP @ diag(alpha)
#     141     R.addcmul_(AP, alpha.reshape(1, -1), value=-1.0)
#
# File ~/miniconda3/envs/falkon-env/lib/python3.9/site-packages/falkon/models/logistic_falkon.py:248, in LogisticFalkon.fit.<locals>.mmv(sol, inner_mmv_, penalty_)
#     246 def mmv(sol, inner_mmv_=inner_mmv, penalty_=penalty):
#     247     sol_a = precond.invA(sol)
# --> 248     knmp_hess = self.loss.knmp_hess(X, ny_X, Y, inner_mmv_, precond.invT(sol_a), opt=self.options)
#     249     return precond.invAt(precond.invTt(knmp_hess).add_(sol_a.mul_(penalty_)))
#
# File ~/miniconda3/envs/falkon-env/lib/python3.9/site-packages/falkon/gsc_losses.py:204, in Loss.knmp_hess(self, X, Xc, Y, f, u, opt)
#     202 inner = self.kernel.mmv(X, Xc, u, opt=opt)
#     203 inner.mul_(self.ddf(Y, f))
# --> 204 outer = self.kernel.mmv(Xc, X, inner, opt=opt)
#     205 outer.mul_(1 / X.shape[0])
#     206 return outer
#
# File ~/miniconda3/envs/falkon-env/lib/python3.9/site-packages/falkon/kernels/kernel.py:287, in Kernel.mmv(self, X1, X2, v, out, opt, kwargs_m1, kwargs_m2)
#     285     params = dataclasses.replace(self.params, **dataclasses.asdict(opt))
#     286 mmv_impl = self._decide_mmv_impl(X1, X2, v, params)
# --> 287 return mmv_impl(
#     288     X1=X1,
#     289     X2=X2,
#     290     v=v,
#     291     kernel=self,
#     292     out=out,
#     293     opt=params,
#     294     kwargs_m1=kwargs_m1,
#     295     kwargs_m2=kwargs_m2,
#     296 )
#
# File ~/miniconda3/envs/falkon-env/lib/python3.9/site-packages/falkon/kernels/distance_kernel.py:397, in GaussianKernel.keops_mmv_impl(self, X1, X2, v, kernel, out, opt, kwargs_m1, kwargs_m2)
#     389 aliases = [
#     390     "x1 = Vi(%d)" % (X1.shape[1]),
#     391     "x2 = Vj(%d)" % (X2.shape[1]),
#     392     "v = Vj(%d)" % (v.shape[1]),
#     393     "g = Pm(%d)" % (self.sigma.shape[0]),
#     394 ]
#     395 other_vars = [self.sigma.to(device=X1.device, dtype=X1.dtype)]
# --> 397 return self.keops_mmv(X1, X2, v, out, formula, aliases, other_vars, opt)
#
# File ~/miniconda3/envs/falkon-env/lib/python3.9/site-packages/falkon/kernels/keops_helpers.py:120, in KeopsKernelMixin.keops_mmv(self, X1, X2, v, out, formula, aliases, other_vars, opt)
#     118 if other_vars is None:
#     119     other_vars = []
# --> 120 return run_keops_mmv(
#     121     X1=X1,
#     122     X2=X2,
#     123     v=v,
#     124     other_vars=other_vars,
#     125     out=out,
#     126     formula=formula,
#     127     aliases=aliases,
#     128     axis=1,
#     129     reduction="Sum",
#     130     opt=opt,
#     131 )
#
# File ~/miniconda3/envs/falkon-env/lib/python3.9/site-packages/falkon/mmv_ops/keops.py:254, in run_keops_mmv(X1, X2, v, other_vars, out, formula, aliases, axis, reduction, opt)
#     238             continue
#     239         args.append(
#     240             (
#     241                 ArgsFmmv(
#    (...)
#     252             )
#     253         )
# --> 254     _start_wait_processes(_single_gpu_method, args)
#     256 return out
#
# File ~/miniconda3/envs/falkon-env/lib/python3.9/site-packages/falkon/mmv_ops/utils.py:77, in _start_wait_processes(target, args)
#      75     processes.append(process)
#      76 for p in processes:
# ---> 77     p.start()
#      78 outputs.extend([p.join() for p in processes])
#      79 return outputs
#
# File ~/miniconda3/envs/falkon-env/lib/python3.9/threading.py:904, in Thread.start(self)
#     902         del _limbo[self]
#     903     raise
# --> 904 self._started.wait()
#
# File ~/miniconda3/envs/falkon-env/lib/python3.9/threading.py:581, in Event.wait(self, timeout)
#     579 signaled = self._flag
#     580 if not signaled:
# --> 581     signaled = self._cond.wait(timeout)
#     582 return signaled
#
# File ~/miniconda3/envs/falkon-env/lib/python3.9/threading.py:312, in Condition.wait(self, timeout)
#     310 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     311     if timeout is None:
# --> 312         waiter.acquire()
#     313         gotit = True
#     314     else:
#
# KeyboardInterrupt:

# %%
t_list
# Out:
# []

# %%
plt.hist(t_list, bins=8)
# Out:
# (array([1., 9., 5., 2., 1., 1., 0., 1.]),
#  array([-1.17207718, -1.15296841, -1.13385963, -1.11475086, -1.09564209,
#         -1.07653332, -1.05742455, -1.03831577, -1.019207  ]),
#  <BarContainer object of 8 artists>)

# %%
feature
# Out:
# tensor([[6.0911e-01],
#         [3.0031e+00],
#         [2.0023e+00],
#         ...,
#         [5.6399e-01],
#         [2.5259e-01],
#         [1.8581e-04]])
